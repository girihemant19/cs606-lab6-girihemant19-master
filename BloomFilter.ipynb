# %% [markdown]
# # Bloom Filter
#
# The Bloom Filtering is a technique that is popularly used for setting a filter on a stream so that only the items that have been already seen before. So it allows all stream elements whose keys are in a stream $S$ while rejecting most of the stream elements whose keys are not in $S$.

# %% [markdown]
# First define some helper methdos that can help in the implementation.

# %%
# We will use the bitarray library for defining the hash table
import numpy as np
from bitarray import bitarray
import random

# %%
# ca and cb are hash function co-efficients
# val is the value to be hashed
# p is the current size of the hash table (the mod part, find a large prime number for this that is >p)
oneLargePrime = 28663
def hashFunc(ca, cb, val, p):
    return (ca*val + cb) % p

# %%
# Now set to 1 in the bitarray b from hashFunc()

def updateFilter(pos, b): 
    b[pos] = 1

# %% [markdown]
# You all are aware of the probability relationship in Bom Filters which can be given by:
#
# $P = (1 - (1-\frac{1}{n})^{km})^k$
#
# where n is the size of the bit-array and there are m items to be filtered.
#
# In the following function set the size of the hash table (prime) which can be found out by using the formula derived from the above one as:
#
# $n = -\frac{m\ln P}{(ln 2)^2}$
#
# Additionally the number of hash functions can be computed as :
#
# $k = \frac{n}{m} ln2$

# %% [markdown]
# Now input the data list (of emails from /email directory)

# %%
import csv
email_list=[]
with open('/home/hemant/Desktop/cs606-lab6-girihemant19/email/train.csv','rt')as f:
    email_list = [x.rstrip('\n') for x in f]
#print(email_list)

# %% [markdown]
# For each of the emails, find the unicode sum for all of it's characters using ord() function

# %%
email_unicode_sum_list = [sum([ord(char) for char in email]) for email in email_list]
#print(email_unicode_sum_list)

# %%
# set the size of the hash table (which is a bitarray)
import numpy as np
accuracy=.001
p = -int(round(((len(email_list)*(np.log(accuracy)))/(np.log(2)**2))))
p
# Out:
# 28755

# %%
#no. of hash function
m=len(email_list)#size of email list
n=p#size of bitarray
k=int(round(np.log(2)*(n/m)))#no of hash function
k
# Out:
# 10

# %%
# initialise bloom filterz
bloom_filter = bitarray(p)
# set all bits to 0
bloom_filter[:] = False
#print("Bloom Filter:", bloom_filter)

# %%
# now generate k hash functions using random integers for ca and cb and maximum size p
def generateHashFunc(k1):
  #List of k random coefficients
  randomCoeffList = []
  # ADD CODE TO FILL UP randomCoeffList
  while k1 > 0:
    # Get a random shingle ID.
    randIndex = random.randint(0, max(email_unicode_sum_list))
  
    # Ensure that each random number is unique.
    while randIndex in randomCoeffList:
        randIndex = random.randint(0, max(email_unicode_sum_list)) 
    
    # Add the random number to the list.
    randomCoeffList.append(randIndex)
    k1 = k1 - 1
    
  return randomCoeffList
    
a = generateHashFunc(k)
b = generateHashFunc(k)
a,b
# Out:
# ([1950, 1740, 1083, 2774, 1827, 1198, 1933, 2458, 1835, 3295],
#  [3209, 2223, 2289, 141, 2834, 2935, 2442, 3532, 72, 3210])

# %% [markdown]
# Use the unicode sums as the val in hashFunc() to hash each email

# %%
hash_list=[]
l=[]
l1=[]
#count=0
for i in range(0,k):
    c=a[i]
    d=b[i]
    hash_list.append([hashFunc(c,d,unicode_sum,oneLargePrime) for unicode_sum  in email_unicode_sum_list])
    #print((hash_list))
    #print("#############################################################")
    #print(bloom_filter)
    l.append(hash_list[i])
    [updateFilter(index, bloom_filter) for index in l[i]]
    #count=count+1
    #print(bloom_filter)
    #l1.append(bloom_filter)
    hash_list[i]=[]
#print(bloom_filter.count(True))
#print(l[1])

# %% [markdown]
# Now input the test data and for every data, write the following check() function where it will go over the k hash functions and see if the email has been seen or not. If any of the bit is the bitarray is false, then the email does not exist else there is a probability P that it exists.

# %%
email_list_test=[]
with open('/home/hemant/Desktop/cs606-lab6-girihemant19/email/test.csv','rt')as f:
    email_list_test = [x.rstrip('\n') for x in f]
email_unicode_sum_list_test = [sum([ord(char) for char in email]) for email in email_list_test]
#(email_unicode_sum_list_test)
email_list_test[599]
# Out:
# 'rm.south@cyberqindia.com'

# %% [markdown]
# For the test data, show what is the value of P, what is size of bit-array, and how many are definietly not present, how many are probably present, and how many false positives are there in the bit array.

# %%
count1=0
count2=0

for i in range(0,k):
    for email in email_list_test:
        if bloom_filter[hashFunc(a[0],b[0],sum([ord(char) for char in email]),oneLargePrime)] == True: 
            print(email   ,"------------------------->has ALREADY been seen");
            count1=count1+1
        else:
            print(email   ,"------------------------->has NOT been seen");
            count2=count2+1
    print("######################################################################")
# Out:
# bmcallanoo@deliciousdays.com ------------------------->has ALREADY been seen
# pperillo9v@bbc.co.uk ------------------------->has ALREADY been seen
# gduddell62@drupal.org ------------------------->has ALREADY been seen
# cclowesql@godaddy.com ------------------------->has ALREADY been seen
# eoxtonra@gmpg.org ------------------------->has ALREADY been seen
# krawpb@amazon.co.uk ------------------------->has ALREADY been seen
# kmcquilkin3c@patch.com ------------------------->has ALREADY been seen
# mspauled6@studiopress.com ------------------------->has ALREADY been seen
# swidmoreov@free.fr ------------------------->has ALREADY been seen
# torteauxf2@webmd.com ------------------------->has ALREADY been seen
# xstoyles2@xinhuanet.com ------------------------->has ALREADY been seen
# nzannotellijn@drupal.org ------------------------->has ALREADY been seen
# gpallyo4@weather.com ------------------------->has ALREADY been seen
# eoconorj8@bloglines.com ------------------------->has ALREADY been seen
# nyakubovb8@theguardian.com ------------------------->has ALREADY been seen
# bforsaithk8@bbb.org ------------------------->has ALREADY been seen
# scollerdp3@spotify.com ------------------------->has ALREADY been seen
# cflooks7u@biblegateway.com ------------------------->has ALREADY been seen
# mspeero6@wordpress.com ------------------------->has ALREADY been seen
# htoppas65@pinterest.com ------------------------->has ALREADY been seen
# jmccourtie94@google.co.jp ------------------------->has ALREADY been seen
# khardibx@vistaprint.com ------------------------->has ALREADY been seen
# ncomberbachrq@ow.ly ------------------------->has ALREADY been seen
# mkwietekoi@tuttocitta.it ------------------------->has ALREADY been seen
# ofoxcroftiv@mac.com ------------------------->has ALREADY been seen
# cnewey6y@tumblr.com ------------------------->has ALREADY been seen
# rlodwickj9@shinystat.com ------------------------->has ALREADY been seen
# thewkin6q@people.com.cn ------------------------->has ALREADY been seen
# bandreoneno@people.com.cn ------------------------->has ALREADY been seen
# adegiorgiooo@sitemeter.com ------------------------->has ALREADY been seen
# aaberkirdopa@hhs.gov ------------------------->has ALREADY been seen
# rribbensos@hp.com ------------------------->has ALREADY been seen
# tvalentinettibk@home.pl ------------------------->has ALREADY been seen
# dgiorgeschi1b@vk.com ------------------------->has ALREADY been seen
# dpicktonrf@zimbio.com ------------------------->has ALREADY been seen
# mhartnellf8@businessinsider.com ------------------------->has ALREADY been seen
# gkarlolaked@smh.com.au ------------------------->has ALREADY been seen
# alimbfy@delicious.com ------------------------->has ALREADY been seen
# gpankettmanrg@nih.gov ------------------------->has ALREADY been seen
# robeirnebw@ehow.com ------------------------->has ALREADY been seen
# vvittoregk@stumbleupon.com ------------------------->has ALREADY been seen
# ngarthlandac@mozilla.com ------------------------->has ALREADY been seen
# skender4j@alexa.com ------------------------->has ALREADY been seen
# cdinglede@alexa.com ------------------------->has ALREADY been seen
# raddionizioob@livejournal.com ------------------------->has ALREADY been seen
# tlusty1u@fc2.com ------------------------->has ALREADY been seen
# rwestwellby@xinhuanet.com ------------------------->has ALREADY been seen
# creidshawpm@stanford.edu ------------------------->has ALREADY been seen
# jpettisalloy@ebay.com ------------------------->has ALREADY been seen
# mcastagnasso49@intel.com ------------------------->has ALREADY been seen
# dmurpheymq@google.com.au ------------------------->has ALREADY been seen
# fmelson8o@usda.gov ------------------------->has ALREADY been seen
# gpersed3@va.gov ------------------------->has ALREADY been seen
# rwalbridge2q@google.pl ------------------------->has ALREADY been seen
# hposnette8x@yale.edu ------------------------->has ALREADY been seen
# khessay82@ftc.gov ------------------------->has ALREADY been seen
# fmactrustey5b@cpanel.net ------------------------->has ALREADY been seen
# gnorthleighg2@patch.com ------------------------->has ALREADY been seen
# hswynley6r@linkedin.com ------------------------->has ALREADY been seen
# aeakly8x@fda.gov ------------------------->has ALREADY been seen
# jmackimm99@fastcompany.com ------------------------->has ALREADY been seen
# hpelchatam@vistaprint.com ------------------------->has ALREADY been seen
# fnairnsep@bbb.org ------------------------->has ALREADY been seen
# tcarnihanj8@toplist.cz ------------------------->has ALREADY been seen
# adolesk3@alibaba.com ------------------------->has ALREADY been seen
# ajennickad@abc.net.au ------------------------->has ALREADY been seen
# bkillelaybm@mozilla.com ------------------------->has ALREADY been seen
# cyateom@wordpress.org ------------------------->has ALREADY been seen
# mgrettonpw@ow.ly ------------------------->has ALREADY been seen
# mgommesrl@nature.com ------------------------->has ALREADY been seen
# dkenefickfq@arstechnica.com ------------------------->has ALREADY been seen
# pmillhilln9@github.io ------------------------->has ALREADY been seen
# darrighettihg@yellowbook.com ------------------------->has ALREADY been seen
# hbrookeseq@washington.edu ------------------------->has ALREADY been seen
# kwaterstone64@bloomberg.com ------------------------->has ALREADY been seen
# esparham17@usgs.gov ------------------------->has ALREADY been seen
# adulintyjc@gmpg.org ------------------------->has ALREADY been seen
# mwestleykp@arstechnica.com ------------------------->has ALREADY been seen
# fmcgrillo1@mediafire.com ------------------------->has ALREADY been seen
# mcomino1i@jiathis.com ------------------------->has ALREADY been seen
# holwenhz@gov.uk ------------------------->has ALREADY been seen
# psedge1o@plala.or.jp ------------------------->has ALREADY been seen
# mrennocks3l@over-blog.com ------------------------->has ALREADY been seen
# fguymerqe@dell.com ------------------------->has ALREADY been seen
# hpollandq6@java.com ------------------------->has ALREADY been seen
# dhaneyc8@mlb.com ------------------------->has ALREADY been seen
# cspenceleyl6@storify.com ------------------------->has ALREADY been seen
# cgulliford3g@sbwire.com ------------------------->has ALREADY been seen
# adrissell5o@blogger.com ------------------------->has ALREADY been seen
# rbortolozziw@desdev.cn ------------------------->has ALREADY been seen
# mschouthedegd@reference.com ------------------------->has ALREADY been seen
# tsarchwell50@reverbnation.com ------------------------->has ALREADY been seen
# fpiolli6b@networksolutions.com ------------------------->has ALREADY been seen
# lphilippeauxax@51.la ------------------------->has ALREADY been seen
# trivesaq@sbwire.com ------------------------->has ALREADY been seen
# ckinchley7j@mlb.com ------------------------->has ALREADY been seen
# mcortin70@cdc.gov ------------------------->has ALREADY been seen
# muebel21@ovh.net ------------------------->has ALREADY been seen
# tvannikovhg@oakley.com ------------------------->has ALREADY been seen
# rdavidsohnee@utexas.edu ------------------------->has ALREADY been seen
# lbellangeral@yahoo.co.jp ------------------------->has ALREADY been seen
# wtipling3x@cpanel.net ------------------------->has ALREADY been seen
# fmccaffreybv@123-reg.co.uk ------------------------->has ALREADY been seen
# mmuttitt46@furl.net ------------------------->has ALREADY been seen
# mdraytonq0@hugedomains.com ------------------------->has ALREADY been seen
# juttridge5f@soup.io ------------------------->has ALREADY been seen
# abouddw@printfriendly.com ------------------------->has ALREADY been seen
# oludeec1@webeden.co.uk ------------------------->has ALREADY been seen
# ysimonassiez@imgur.com ------------------------->has ALREADY been seen
# mdonald3m@domainmarket.com ------------------------->has ALREADY been seen
# elubomirski4c@imageshack.us ------------------------->has ALREADY been seen
# ssent7g@pbs.org ------------------------->has ALREADY been seen
# astandidgedy@google.com ------------------------->has ALREADY been seen
# tlellofa@about.me ------------------------->has ALREADY been seen
# jknapmanhr@tinypic.com ------------------------->has ALREADY been seen
# sweekly30@symantec.com ------------------------->has ALREADY been seen
# tjowsey52@wiley.com ------------------------->has ALREADY been seen
# dstorklf@newyorker.com ------------------------->has ALREADY been seen
# smiltonhy@cornell.edu ------------------------->has ALREADY been seen
# rfitzgeorgebu@barnesandnoble.com ------------------------->has ALREADY been seen
# pmattusovew@altervista.org ------------------------->has ALREADY been seen
# veaglingi@msu.edu ------------------------->has ALREADY been seen
# rclelland1f@artisteer.com ------------------------->has ALREADY been seen
# dcelandof@storify.com ------------------------->has ALREADY been seen
# plakesd2@example.com ------------------------->has ALREADY been seen
# lboatwrightes@netvibes.com ------------------------->has ALREADY been seen
# bbloxsom94@state.tx.us ------------------------->has ALREADY been seen
# cbondy1h@bloglovin.com ------------------------->has ALREADY been seen
# roverellk@nhs.uk ------------------------->has ALREADY been seen
# jkirke1l@vistaprint.com ------------------------->has ALREADY been seen
# sfreckingham9y@ehow.com ------------------------->has ALREADY been seen
# kdozdillkr@virginia.edu ------------------------->has ALREADY been seen
# rricciardiellot@dailymail.co.uk ------------------------->has ALREADY been seen
# zmclardienl@macromedia.com ------------------------->has ALREADY been seen
# ubelseyej@businessweek.com ------------------------->has ALREADY been seen
# ksweetenhamd5@pinterest.com ------------------------->has ALREADY been seen
# mramsdellp4@google.ru ------------------------->has ALREADY been seen
# ppinsent9@usda.gov ------------------------->has ALREADY been seen
# rstiversms@eventbrite.com ------------------------->has ALREADY been seen
# gsculleykq@simplemachines.org ------------------------->has ALREADY been seen
# ojohananovdl@netscape.com ------------------------->has ALREADY been seen
# pmacellarh7@aol.com ------------------------->has ALREADY been seen
# cokice@4shared.com ------------------------->has ALREADY been seen
# mchesterfield3j@nasa.gov ------------------------->has ALREADY been seen
# sceresaop@bizjournals.com ------------------------->has ALREADY been seen
# salbin2a@ed.gov ------------------------->has ALREADY been seen
# spawlaczykee@dyndns.org ------------------------->has ALREADY been seen
# cyearnesgi@creativecommons.org ------------------------->has ALREADY been seen
# nlutas38@examiner.com ------------------------->has ALREADY been seen
# skrishtopaittisbz@addtoany.com ------------------------->has ALREADY been seen
# eextall7l@fema.gov ------------------------->has ALREADY been seen
# dhinstock47@twitpic.com ------------------------->has ALREADY been seen
# dbompassfw@devhub.com ------------------------->has ALREADY been seen
# hnewelln2@ameblo.jp ------------------------->has ALREADY been seen
# solenovik@skype.com ------------------------->has ALREADY been seen
# rwarbyfi@columbia.edu ------------------------->has ALREADY been seen
# hspennockoh@so-net.ne.jp ------------------------->has ALREADY been seen
# mshakelady4q@cloudflare.com ------------------------->has ALREADY been seen
# gbearsmorep5@51.la ------------------------->has ALREADY been seen
# cadamsone2@webmd.com ------------------------->has ALREADY been seen
# mshermanqn@smh.com.au ------------------------->has ALREADY been seen
# jbilovskyq5@people.com.cn ------------------------->has ALREADY been seen
# wdrackfordrd@theglobeandmail.com ------------------------->has ALREADY been seen
# astannahii@spiegel.de ------------------------->has ALREADY been seen
# eprivettai@msn.com ------------------------->has ALREADY been seen
# arutledgenj@noaa.gov ------------------------->has ALREADY been seen
# jheggieao@irs.gov ------------------------->has ALREADY been seen
# bfiggs9d@imdb.com ------------------------->has ALREADY been seen
# yoriganlp@wordpress.com ------------------------->has ALREADY been seen
# mdenisard34@cargocollective.com ------------------------->has ALREADY been seen
# esommerlandjr@stumbleupon.com ------------------------->has ALREADY been seen
# relbourne6k@wikipedia.org ------------------------->has ALREADY been seen
# vpenticooti6@seattletimes.com ------------------------->has ALREADY been seen
# mhubanct@biblegateway.com ------------------------->has ALREADY been seen
# akos4u@hao123.com ------------------------->has ALREADY been seen
# dshoveller8e@nature.com ------------------------->has ALREADY been seen
# gsharper8j@example.com ------------------------->has ALREADY been seen
# aaseyca@nationalgeographic.com ------------------------->has ALREADY been seen
# dgilpinnp@ifeng.com ------------------------->has ALREADY been seen
# jquibella5@japanpost.jp ------------------------->has ALREADY been seen
# msummonsil@netscape.com ------------------------->has ALREADY been seen
# pthorwarthi2@examiner.com ------------------------->has ALREADY been seen
# vbohljefl@theglobeandmail.com ------------------------->has ALREADY been seen
# fgimertb1@unicef.org ------------------------->has ALREADY been seen
# rdanzigpm@plala.or.jp ------------------------->has ALREADY been seen
# amallettdo@tmall.com ------------------------->has ALREADY been seen
# hhansen76@tumblr.com ------------------------->has ALREADY been seen
# rsnelmane8@amazon.co.uk ------------------------->has ALREADY been seen
# jwoodheaddd@cargocollective.com ------------------------->has ALREADY been seen
# oledgley7a@fda.gov ------------------------->has ALREADY been seen
# lluckwellbn@wordpress.org ------------------------->has ALREADY been seen
# gimlawjg@list-manage.com ------------------------->has ALREADY been seen
# gloakesro@facebook.com ------------------------->has ALREADY been seen
# ogissingmv@chron.com ------------------------->has ALREADY been seen
# jbenian7y@is.gd ------------------------->has ALREADY been seen
# nnanip7@altervista.org ------------------------->has ALREADY been seen
# holletnr@smugmug.com ------------------------->has ALREADY been seen
# cposselwhite1s@jigsy.com ------------------------->has ALREADY been seen
# dhutablep1@ft.com ------------------------->has ALREADY been seen
# eneeveid@wp.com ------------------------->has ALREADY been seen
# kmacmeekanc@wikimedia.org ------------------------->has ALREADY been seen
# gswiffen1g@tuttocitta.it ------------------------->has ALREADY been seen
# tgalletly9a@flavors.me ------------------------->has ALREADY been seen
# lglennon1m@disqus.com ------------------------->has ALREADY been seen
# kegleofgermany4o@wordpress.org ------------------------->has ALREADY been seen
# agarrit3s@eepurl.com ------------------------->has ALREADY been seen
# jheijnenj@omniture.com ------------------------->has ALREADY been seen
# bmateus2x@wired.com ------------------------->has ALREADY been seen
# baudisseh@aboutads.info ------------------------->has ALREADY been seen
# rceaplencx@soundcloud.com ------------------------->has ALREADY been seen
# rsabbenkl@edublogs.org ------------------------->has ALREADY been seen
# dkelwaybamberqg@hhs.gov ------------------------->has ALREADY been seen
# aboullinjb@chronoengine.com ------------------------->has ALREADY been seen
# mdwyr3a@flickr.com ------------------------->has ALREADY been seen
# jgealyp7@dailymail.co.uk ------------------------->has ALREADY been seen
# bcoverleyij@reference.com ------------------------->has ALREADY been seen
# fseiffertpo@w3.org ------------------------->has ALREADY been seen
# lwooland2w@merriam-webster.com ------------------------->has ALREADY been seen
# mbalducci8d@mediafire.com ------------------------->has ALREADY been seen
# jmcneachtainmu@elpais.com ------------------------->has ALREADY been seen
# ebiddyek@tripod.com ------------------------->has ALREADY been seen
# emauserq1@google.ca ------------------------->has ALREADY been seen
# cfolds9k@multiply.com ------------------------->has ALREADY been seen
# ygaynes7@java.com ------------------------->has ALREADY been seen
# mtreendoh@alexa.com ------------------------->has ALREADY been seen
# azima8b@state.tx.us ------------------------->has ALREADY been seen
# amaylott1g@pagesperso-orange.fr ------------------------->has ALREADY been seen
# cheffero2@dedecms.com ------------------------->has ALREADY been seen
# krixj4@unesco.org ------------------------->has ALREADY been seen
# bfryattm8@jimdo.com ------------------------->has ALREADY been seen
# cknivett4h@dagondesign.com ------------------------->has ALREADY been seen
# btiemanll@cornell.edu ------------------------->has ALREADY been seen
# jsawdon7o@booking.com ------------------------->has ALREADY been seen
# shutcheon1r@noaa.gov ------------------------->has ALREADY been seen
# bwilcockeqs@epa.gov ------------------------->has ALREADY been seen
# dsiviter7b@soundcloud.com ------------------------->has ALREADY been seen
# cmcgowanhi@youtu.be ------------------------->has ALREADY been seen
# jparchmentgb@mozilla.com ------------------------->has ALREADY been seen
# sschwaiger9x@japanpost.jp ------------------------->has ALREADY been seen
# skarlqvistdc@unc.edu ------------------------->has ALREADY been seen
# anetley85@g.co ------------------------->has ALREADY been seen
# akemberybt@nbcnews.com ------------------------->has ALREADY been seen
# mbreffit8h@independent.co.uk ------------------------->has ALREADY been seen
# lperrinon@artisteer.com ------------------------->has ALREADY been seen
# rplaistowe9u@quantcast.com ------------------------->has ALREADY been seen
# kfishpoole7y@dedecms.com ------------------------->has ALREADY been seen
# jwrey78@columbia.edu ------------------------->has ALREADY been seen
# drawlingsonol@about.me ------------------------->has ALREADY been seen
# agirathspp@multiply.com ------------------------->has ALREADY been seen
# dwyon77@sohu.com ------------------------->has ALREADY been seen
# solner2g@linkedin.com ------------------------->has ALREADY been seen
# hscamal1k@moonfruit.com ------------------------->has ALREADY been seen
# hvanderhoevenei@studiopress.com ------------------------->has ALREADY been seen
# gprayerci@jalbum.net ------------------------->has ALREADY been seen
# dharfleet81@facebook.com ------------------------->has ALREADY been seen
# vmettetald0@symantec.com ------------------------->has ALREADY been seen
# cdewfallmo@salon.com ------------------------->has ALREADY been seen
# jgumn44@yale.edu ------------------------->has ALREADY been seen
# fpourveerpe@mediafire.com ------------------------->has ALREADY been seen
# bmonteza7@behance.net ------------------------->has ALREADY been seen
# dtorresib6@dion.ne.jp ------------------------->has ALREADY been seen
# jlazer8a@businesswire.com ------------------------->has ALREADY been seen
# ekilliner39@bloomberg.com ------------------------->has ALREADY been seen
# wtitfordj7@ustream.tv ------------------------->has ALREADY been seen
# lstoppard2h@stumbleupon.com ------------------------->has ALREADY been seen
# afeatonby7t@seattletimes.com ------------------------->has ALREADY been seen
# lcruisegj@altervista.org ------------------------->has ALREADY been seen
# cbrecha3@guardian.co.uk ------------------------->has ALREADY been seen
# dmcenteggartky@bigcartel.com ------------------------->has ALREADY been seen
# elohdenne@umn.edu ------------------------->has ALREADY been seen
# tlydiarddi@smugmug.com ------------------------->has ALREADY been seen
# ldoeg4y@unblog.fr ------------------------->has ALREADY been seen
# ailyasc5@prweb.com ------------------------->has ALREADY been seen
# mseeman9s@miibeian.gov.cn ------------------------->has ALREADY been seen
# gbarnewall81@unesco.org ------------------------->has ALREADY been seen
# ipulhosterf5@csmonitor.com ------------------------->has ALREADY been seen
# jgrundyj4@g.co ------------------------->has ALREADY been seen
# kbetonoc@usda.gov ------------------------->has ALREADY been seen
# khalleylh@merriam-webster.com ------------------------->has ALREADY been seen
# lstein1m@wunderground.com ------------------------->has ALREADY been seen
# hpaffleyaa@walmart.com ------------------------->has ALREADY been seen
# gdinzeym3@tuttocitta.it ------------------------->has ALREADY been seen
# rweall8d@alibaba.com ------------------------->has ALREADY been seen
# nsainthill2k@technorati.com ------------------------->has ALREADY been seen
# rtebbittq7@ebay.com ------------------------->has ALREADY been seen
# crosewarneny@fotki.com ------------------------->has ALREADY been seen
# jjerosch6o@sogou.com ------------------------->has ALREADY been seen
# mfebreep@fda.gov ------------------------->has ALREADY been seen
# ccooter0@miitbeian.gov.cn ------------------------->has ALREADY been seen
# cdwerryhouseaz@diigo.com ------------------------->has ALREADY been seen
# jluna42@hostgator.com ------------------------->has ALREADY been seen
# epurslowow@google.cn ------------------------->has ALREADY been seen
# sstainska@fda.gov ------------------------->has ALREADY been seen
# qmebius9l@linkedin.com ------------------------->has ALREADY been seen
# airon7d@cisco.com ------------------------->has ALREADY been seen
# eattwooll10@mayoclinic.com ------------------------->has ALREADY been seen
# jdomekiu@infoseek.co.jp ------------------------->has ALREADY been seen
# ntrunksmw@apache.org ------------------------->has ALREADY been seen
# slangshaw1d@google.de ------------------------->has ALREADY been seen
# wbirtles8y@house.gov ------------------------->has ALREADY been seen
# mdallowayfe@delicious.com ------------------------->has ALREADY been seen
# vtarpeyk2@creativecommons.org ------------------------->has ALREADY been seen
# kdunankp@newyorker.com ------------------------->has ALREADY been seen
# eaizicpw@va.gov ------------------------->has ALREADY been seen
# lshuttleworth70@elegantthemes.com ------------------------->has ALREADY been seen
# skloster1n@google.ca ------------------------->has ALREADY been seen
# ailewicznu@360.cn ------------------------->has ALREADY been seen
# cgelsthorpet@mail.ru ------------------------->has ALREADY been seen
# gghiriardelli11@angelfire.com ------------------------->has ALREADY been seen
# mwillmott8z@squidoo.com ------------------------->has ALREADY been seen
# edibbertlh@prweb.com ------------------------->has ALREADY been seen
# fmatura3f@flickr.com ------------------------->has ALREADY been seen
# mgartrell6h@ucsd.edu ------------------------->has ALREADY been seen
# dmacinerneyq2@twitter.com ------------------------->has ALREADY been seen
# ugamlyn8y@printfriendly.com ------------------------->has ALREADY been seen
# dshillitoear@irs.gov ------------------------->has ALREADY been seen
# tjeryqa@unblog.fr ------------------------->has ALREADY been seen
# sscamel63@opera.com ------------------------->has ALREADY been seen
# fpablo1b@cmu.edu ------------------------->has ALREADY been seen
# alauxhv@myspace.com ------------------------->has ALREADY been seen
# cburgett92@engadget.com ------------------------->has ALREADY been seen
# cblanchetpt@posterous.com ------------------------->has ALREADY been seen
# rhandsheartow@disqus.com ------------------------->has ALREADY been seen
# cdavidovitz4s@bigcartel.com ------------------------->has ALREADY been seen
# asturridgeg9@blogtalkradio.com ------------------------->has ALREADY been seen
# sesbybt@newyorker.com ------------------------->has ALREADY been seen
# tguilleds@google.ca ------------------------->has ALREADY been seen
# fgeraghty6i@techcrunch.com ------------------------->has ALREADY been seen
# spasticznyki7@ow.ly ------------------------->has ALREADY been seen
# bwesthofer23@springer.com ------------------------->has ALREADY been seen
# blennielc@weather.com ------------------------->has ALREADY been seen
# fzavattaricc@mit.edu ------------------------->has ALREADY been seen
# wpoyzer2m@senate.gov ------------------------->has ALREADY been seen
# ddiggin2j@umn.edu ------------------------->has ALREADY been seen
# cquenell7w@ted.com ------------------------->has ALREADY been seen
# npidlerkq@pen.io ------------------------->has ALREADY been seen
# afordhamd@ihg.com ------------------------->has ALREADY been seen
# mginnalyc8@virginia.edu ------------------------->has ALREADY been seen
# spehrssoncu@nytimes.com ------------------------->has ALREADY been seen
# lzimabj@fotki.com ------------------------->has ALREADY been seen
# jgreenhousejz@oracle.com ------------------------->has ALREADY been seen
# bmundowok@e-recht24.de ------------------------->has ALREADY been seen
# eedessb9@bing.com ------------------------->has ALREADY been seen
# cchavesi2@msn.com ------------------------->has ALREADY been seen
# nandor7v@geocities.jp ------------------------->has ALREADY been seen
# orantoull1v@yelp.com ------------------------->has ALREADY been seen
# senticknaph2@java.com ------------------------->has ALREADY been seen
# coflynnb@sina.com.cn ------------------------->has ALREADY been seen
# jblundelg5@jimdo.com ------------------------->has ALREADY been seen
# efullstone7u@un.org ------------------------->has ALREADY been seen
# sconanem@wikipedia.org ------------------------->has ALREADY been seen
# dabadm@tuttocitta.it ------------------------->has ALREADY been seen
# ilocklessgv@ca.gov ------------------------->has ALREADY been seen
# lgaitungqz@weather.com ------------------------->has ALREADY been seen
# tvaiseyrq@va.gov ------------------------->has ALREADY been seen
# landrewarthan1@arizona.edu ------------------------->has ALREADY been seen
# pdallywatermy@qq.com ------------------------->has ALREADY been seen
# oeakins6t@typepad.com ------------------------->has ALREADY been seen
# melcouxbf@about.me ------------------------->has ALREADY been seen
# hkleinber8t@bing.com ------------------------->has ALREADY been seen
# hnelseyir@yahoo.co.jp ------------------------->has ALREADY been seen
# gdabbesmg@gmpg.org ------------------------->has ALREADY been seen
# cstranio4u@unesco.org ------------------------->has ALREADY been seen
# mstarrs1w@apache.org ------------------------->has ALREADY been seen
# hbaudinetl8@opensource.org ------------------------->has ALREADY been seen
# ynotonew@msn.com ------------------------->has ALREADY been seen
# klacosterp@biblegateway.com ------------------------->has ALREADY been seen
# dpaigef4@sciencedaily.com ------------------------->has ALREADY been seen
# ajoskowicz4m@biglobe.ne.jp ------------------------->has ALREADY been seen
# gocuolahan5m@army.mil ------------------------->has ALREADY been seen
# ggee3j@uol.com.br ------------------------->has ALREADY been seen
# cbalnavelz@istockphoto.com ------------------------->has ALREADY been seen
# vkenn17@opera.com ------------------------->has ALREADY been seen
# sstillwell3b@typepad.com ------------------------->has ALREADY been seen
# mcaigds@t.co ------------------------->has ALREADY been seen
# vpritchettrj@hubpages.com ------------------------->has ALREADY been seen
# odougharty4b@cloudflare.com ------------------------->has ALREADY been seen
# bgresham89@skyrock.com ------------------------->has ALREADY been seen
# cguilfoylejh@arizona.edu ------------------------->has ALREADY been seen
# djammepx@columbia.edu ------------------------->has ALREADY been seen
# gfrise96@godaddy.com ------------------------->has ALREADY been seen
# bbrompton1d@oracle.com ------------------------->has ALREADY been seen
# jeller5v@example.com ------------------------->has ALREADY been seen
# mliquorish8f@t.co ------------------------->has ALREADY been seen
# gwhitleybu@livejournal.com ------------------------->has ALREADY been seen
# krozziera9@answers.com ------------------------->has ALREADY been seen
# ltremoulet8g@indiegogo.com ------------------------->has ALREADY been seen
# ocuddyl@soup.io ------------------------->has ALREADY been seen
# cguillartkz@cbslocal.com ------------------------->has ALREADY been seen
# srenner6g@bloglovin.com ------------------------->has ALREADY been seen
# tjunenn@forbes.com ------------------------->has ALREADY been seen
# slubbockbw@histats.com ------------------------->has ALREADY been seen
# gmacallasterau@parallels.com ------------------------->has ALREADY been seen
# mcarsberg6i@columbia.edu ------------------------->has ALREADY been seen
# lloukeso5@ihg.com ------------------------->has ALREADY been seen
# sbotterman6g@edublogs.org ------------------------->has ALREADY been seen
# facarson3h@surveymonkey.com ------------------------->has ALREADY been seen
# pbyre4@prnewswire.com ------------------------->has ALREADY been seen
# cvamplusfb@boston.com ------------------------->has ALREADY been seen
# bmaylouri3@ustream.tv ------------------------->has ALREADY been seen
# lyakuntsovgv@trellian.com ------------------------->has ALREADY been seen
# tmctear5h@1688.com ------------------------->has ALREADY been seen
# tfurseh1@cdbaby.com ------------------------->has ALREADY been seen
# mdrysdellkf@jiathis.com ------------------------->has ALREADY been seen
# wladburykc@virginia.edu ------------------------->has ALREADY been seen
# bsanchiz8l@jiathis.com ------------------------->has ALREADY been seen
# ldoretqb@wordpress.com ------------------------->has ALREADY been seen
# btoffaloni8b@technorati.com ------------------------->has ALREADY been seen
# cauton2s@hc360.com ------------------------->has ALREADY been seen
# lvandermerwebd@abc.net.au ------------------------->has ALREADY been seen
# merbain4x@disqus.com ------------------------->has ALREADY been seen
# tgwinnellle@nature.com ------------------------->has ALREADY been seen
# tgarlanday@microsoft.com ------------------------->has ALREADY been seen
# ccantillion2u@tripod.com ------------------------->has ALREADY been seen
# oaizkovitchgr@sciencedirect.com ------------------------->has ALREADY been seen
# tantonellipu@jiathis.com ------------------------->has ALREADY been seen
# ahartgillog@xinhuanet.com ------------------------->has ALREADY been seen
# ffilpoib@theguardian.com ------------------------->has ALREADY been seen
# khallgoughci@hud.gov ------------------------->has ALREADY been seen
# ikobschjp@geocities.com ------------------------->has ALREADY been seen
# sbly1q@newsvine.com ------------------------->has ALREADY been seen
# rgaukrodge32@webmd.com ------------------------->has ALREADY been seen
# ebarthelmerm@list-manage.com ------------------------->has ALREADY been seen
# jbryersfx@slashdot.org ------------------------->has ALREADY been seen
# tlowrey1q@altervista.org ------------------------->has ALREADY been seen
# jcutcheedr@reuters.com ------------------------->has ALREADY been seen
# ldietzjy@live.com ------------------------->has ALREADY been seen
# rmckunepj@amazonaws.com ------------------------->has ALREADY been seen
# acolvill9m@wix.com ------------------------->has ALREADY been seen
# dpeaceyfs@narod.ru ------------------------->has ALREADY been seen
# sbridelle5@creativecommons.org ------------------------->has ALREADY been seen
# aminthorpeml@newyorker.com ------------------------->has ALREADY been seen
# mkirmondc6@reference.com ------------------------->has ALREADY been seen
# teacott54@oracle.com ------------------------->has ALREADY been seen
# cdoylandr6@qq.com ------------------------->has ALREADY been seen
# fpesticciolb@zdnet.com ------------------------->has ALREADY been seen
# ahuntingjh@nytimes.com ------------------------->has ALREADY been seen
# rworling8a@answers.com ------------------------->has ALREADY been seen
# abavesterc@domainmarket.com ------------------------->has ALREADY been seen
# amemoryo4@guardian.co.uk ------------------------->has ALREADY been seen
# bgammelhu@ow.ly ------------------------->has ALREADY been seen
# hstrettondj@netscape.com ------------------------->has ALREADY been seen
# craultbl@hatena.ne.jp ------------------------->has ALREADY been seen
# cpoinsett1u@google.com.au ------------------------->has ALREADY been seen
# gdeppend2@chron.com ------------------------->has ALREADY been seen
# dboijit@cam.ac.uk ------------------------->has ALREADY been seen
# slayland5r@blogger.com ------------------------->has ALREADY been seen
# fpimm5j@abc.net.au ------------------------->has ALREADY been seen
# mbearmanh4@craigslist.org ------------------------->has ALREADY been seen
# aaluardfr@oracle.com ------------------------->has ALREADY been seen
# dpalliserqo@wikipedia.org ------------------------->has ALREADY been seen
# dswattonl4@google.pl ------------------------->has ALREADY been seen
# jbaroschlw@geocities.jp ------------------------->has ALREADY been seen
# rcausleyam@youku.com ------------------------->has ALREADY been seen
# mbathoweak@fema.gov ------------------------->has ALREADY been seen
# amitskevichbj@google.nl ------------------------->has ALREADY been seen
# braouli5@instagram.com ------------------------->has ALREADY been seen
# mpettisct@techcrunch.com ------------------------->has ALREADY been seen
# poleszczakgo@cnbc.com ------------------------->has ALREADY been seen
# bcranchkb@state.gov ------------------------->has ALREADY been seen
# kmackettqq@upenn.edu ------------------------->has ALREADY been seen
# slamortf1@canalblog.com ------------------------->has ALREADY been seen
# uboyingtonpn@amazon.com ------------------------->has ALREADY been seen
# bcarles3e@ameblo.jp ------------------------->has ALREADY been seen
# rwellbeloved3r@storify.com ------------------------->has ALREADY been seen
# ibrandassi8r@economist.com ------------------------->has ALREADY been seen
# gferrieroih@amazon.co.uk ------------------------->has ALREADY been seen
# asailorlq@etsy.com ------------------------->has ALREADY been seen
# scastagneri79@columbia.edu ------------------------->has ALREADY been seen
# mlileye6@1688.com ------------------------->has ALREADY been seen
# kseiterpf@tmall.com ------------------------->has ALREADY been seen
# tdallmanjy@buzzfeed.com ------------------------->has ALREADY been seen
# jmcaviycy@zimbio.com ------------------------->has ALREADY been seen
# tcyseleyk7@ebay.co.uk ------------------------->has ALREADY been seen
# nfigiovannia4@canalblog.com ------------------------->has ALREADY been seen
# tskeeteje@yelp.com ------------------------->has ALREADY been seen
# bhaugeh3c@washingtonpost.com ------------------------->has ALREADY been seen
# tdumbarton8j@dedecms.com ------------------------->has ALREADY been seen
# kweighk6@state.tx.us ------------------------->has ALREADY been seen
# hmuddicliffep@amazon.co.jp ------------------------->has ALREADY been seen
# apachtox@tripod.com ------------------------->has ALREADY been seen
# bhayterc0@vk.com ------------------------->has ALREADY been seen
# fdullingnw@de.vu ------------------------->has ALREADY been seen
# shebbornepe@newsvine.com ------------------------->has ALREADY been seen
# friddef3@examiner.com ------------------------->has ALREADY been seen
# wscocroftkx@printfriendly.com ------------------------->has ALREADY been seen
# gbattyab@weibo.com ------------------------->has ALREADY been seen
# jshipm9@narod.ru ------------------------->has ALREADY been seen
# cbollettijz@mail.ru ------------------------->has ALREADY been seen
# msothcotteh@google.com.au ------------------------->has ALREADY been seen
# dkobiela77@opera.com ------------------------->has ALREADY been seen
# hferrarottihd@sun.com ------------------------->has ALREADY been seen
# egurrkx@google.pl ------------------------->has ALREADY been seen
# driguard6n@seattletimes.com ------------------------->has ALREADY been seen
# equesnech@google.ca ------------------------->has ALREADY been seen
# bcranage9j@about.me ------------------------->has ALREADY been seen
# lmilmoej0@hud.gov ------------------------->has ALREADY been seen
# cbrownhilll9@unc.edu ------------------------->has ALREADY been seen
# lbinnyhc@nymag.com ------------------------->has ALREADY been seen
# vstolliih@wordpress.org ------------------------->has ALREADY been seen
# in.pune.careers@3dplmsoftware.com ------------------------->has NOT been seen
# hr.admin@aahlaad.com ------------------------->has ALREADY been seen
# akash.shivnarayan@accenture.com ------------------------->has NOT been seen
# aruna.b.reddy@accenture.com ------------------------->has ALREADY been seen
# azharuddin.md@accenture.com ------------------------->has ALREADY been seen
# keerthi.raj@accenture.com ------------------------->has ALREADY been seen
# mailer@mailer.accenture.com ------------------------->has NOT been seen
# sudha.p.kumar@accenture.com ------------------------->has NOT been seen
# t.rahangdale@accenture.com ------------------------->has NOT been seen
# ankita.priya@accolite.com ------------------------->has ALREADY been seen
# mr1@acculogix.com ------------------------->has NOT been seen
# pr@acculogix.com ------------------------->has ALREADY been seen
# hr@accuversa.com ------------------------->has ALREADY been seen
# aparna.samal@adecco.co.in ------------------------->has ALREADY been seen
# neha.sahu@adecco.co.in ------------------------->has ALREADY been seen
# nisha.singh@adecco.co.in ------------------------->has ALREADY been seen
# mamatha.bamana@adecco.co.in ------------------------->has ALREADY been seen
# veena.venugopal@adecco.co.in ------------------------->has NOT been seen
# rohithnu@aditi.com ------------------------->has ALREADY been seen
# lathal@aditi.com ------------------------->has ALREADY been seen
# raghavendrab@aditi.com ------------------------->has ALREADY been seen
# shyamalapv@aditi.com ------------------------->has ALREADY been seen
# rohitku@adobe.com ------------------------->has ALREADY been seen
# careers@air-watch.com ------------------------->has ALREADY been seen
# support@ajr2.com ------------------------->has NOT been seen
# Careers@aletheia.co.in ------------------------->has ALREADY been seen
# lguntuma@allegisgroup.com ------------------------->has ALREADY been seen
# ssundare@allegisgroup.com ------------------------->has ALREADY been seen
# careers@alphalinxtech.com ------------------------->has ALREADY been seen
# archana.mehta@altisource.com ------------------------->has NOT been seen
# oliver.dsouza@altisource.com ------------------------->has NOT been seen
# ramchan@amazon.com ------------------------->has ALREADY been seen
# kirthiks@amazon.com ------------------------->has ALREADY been seen
# indujar@amazon.com ------------------------->has ALREADY been seen
# aritran@amazon.com ------------------------->has ALREADY been seen
# anisingh@amazon.com ------------------------->has ALREADY been seen
# deepama@amazon.com ------------------------->has NOT been seen
# edivya@amazon.com ------------------------->has ALREADY been seen
# suprita@amazon.com ------------------------->has NOT been seen
# risseyb@amazon.com ------------------------->has ALREADY been seen
# samtac@amazon.com ------------------------->has ALREADY been seen
# vivekmo@amazon.com ------------------------->has ALREADY been seen
# indiacareers@amdocs.com ------------------------->has ALREADY been seen
# info@aptean.com ------------------------->has ALREADY been seen
# Rajeshwari.Siddappa@aptean.com ------------------------->has ALREADY been seen
# Nishat.Fatma@aptean.com ------------------------->has NOT been seen
# nalinig@arcadix.com ------------------------->has ALREADY been seen
# jdivya.aranha@arcadix.com ------------------------->has ALREADY been seen
# jobs@arcadix.com ------------------------->has ALREADY been seen
# deepak@arcusinfotech.com ------------------------->has ALREADY been seen
# shamna@asapinfosystems.com ------------------------->has NOT been seen
# fefs@aspiresys.com ------------------------->has ALREADY been seen
# jobs@atlassystems.com ------------------------->has ALREADY been seen
# shilpa.veerabhadraiah@atlassystems.com ------------------------->has ALREADY been seen
# biju@augustainfotech.com ------------------------->has ALREADY been seen
# Praveen.d@avvasinfotech.com ------------------------->has NOT been seen
# bgsoftech@gmail.com ------------------------->has ALREADY been seen
# dilipsharma@blkashyap.com ------------------------->has ALREADY been seen
# ers@bsil.com ------------------------->has NOT been seen
# fixed-term.akanksha.sahay@in.bosch.com ------------------------->has NOT been seen
# hr@byt-eye.com ------------------------->has NOT been seen
# hr@calit8.com ------------------------->has NOT been seen
# contactus@calit8.com ------------------------->has NOT been seen
# Careers@cangonetworks.com ------------------------->has ALREADY been seen
# harsh.doshi@capgemini.com ------------------------->has ALREADY been seen
# jisha.balakrishnan@capgemini.com ------------------------->has NOT been seen
# kalpana.athi@capgemini.com ------------------------->has ALREADY been seen
# reshma.r@capgemini.com ------------------------->has ALREADY been seen
# vijaykumar.ninganure@capgemini.com ------------------------->has NOT been seen
# sailaja.yakasiri@capgemini.com ------------------------->has ALREADY been seen
# sunetra.das@capgemini.com ------------------------->has ALREADY been seen
# monika.shukla@capgemini.com ------------------------->has NOT been seen
# avijit.datta@capgemini.com ------------------------->has ALREADY been seen
# anand.subramanian@careernet.co.in ------------------------->has NOT been seen
# akankshya.dutta@careernet.co.in ------------------------->has NOT been seen
# sindhu.raman@careernet.co.in ------------------------->has NOT been seen
# hr@catalystwebexperts.com ------------------------->has ALREADY been seen
# lakshmi@centrisinfotech.com ------------------------->has ALREADY been seen
# jackson.johnson@centurylink.com ------------------------->has ALREADY been seen
# Niharika.Kala@centurylink.com ------------------------->has ALREADY been seen
# joseph@ceotalentsearch.com ------------------------->has ALREADY been seen
# ngottigundala@ciber.com ------------------------->has ALREADY been seen
# info@cigniti.com ------------------------->has ALREADY been seen
# wearehiring@cigniti.com ------------------------->has ALREADY been seen
# freshers@citagus.com ------------------------->has ALREADY been seen
# gayathri.srinivas@citrix.com ------------------------->has ALREADY been seen
# jobs@clifftechnologies.com ------------------------->has ALREADY been seen
# Manju.D2@cognizant.com ------------------------->has ALREADY been seen
# Mohammed.Moin@cognizant.com ------------------------->has ALREADY been seen
# priyanka.pramanick@cognizant.com ------------------------->has NOT been seen
# Raghavendra.Pawarr.c@cognizant.com ------------------------->has ALREADY been seen
# vigneswari.sivanandham@cognizant.com ------------------------->has NOT been seen
# suparna.dhar@cognizant.com ------------------------->has ALREADY been seen
# reshma.n@confrontsolutions.com ------------------------->has NOT been seen
# jobopenings@compassitesinc.com ------------------------->has ALREADY been seen
# jobs@corasent.com ------------------------->has NOT been seen
# pramila@covenantindia.net ------------------------->has ALREADY been seen
# monicae@covenantindia.net ------------------------->has ALREADY been seen
# smathur@csc.com ------------------------->has ALREADY been seen
# rm.south@cyberqindia.com ------------------------->has ALREADY been seen
# ######################################################################
# bmcallanoo@deliciousdays.com ------------------------->has ALREADY been seen
# pperillo9v@bbc.co.uk ------------------------->has ALREADY been seen
# gduddell62@drupal.org ------------------------->has ALREADY been seen
# cclowesql@godaddy.com ------------------------->has ALREADY been seen
# eoxtonra@gmpg.org ------------------------->has ALREADY been seen
# krawpb@amazon.co.uk ------------------------->has ALREADY been seen
# kmcquilkin3c@patch.com ------------------------->has ALREADY been seen
# mspauled6@studiopress.com ------------------------->has ALREADY been seen
# swidmoreov@free.fr ------------------------->has ALREADY been seen
# torteauxf2@webmd.com ------------------------->has ALREADY been seen
# xstoyles2@xinhuanet.com ------------------------->has ALREADY been seen
# nzannotellijn@drupal.org ------------------------->has ALREADY been seen
# gpallyo4@weather.com ------------------------->has ALREADY been seen
# eoconorj8@bloglines.com ------------------------->has ALREADY been seen
# nyakubovb8@theguardian.com ------------------------->has ALREADY been seen
# bforsaithk8@bbb.org ------------------------->has ALREADY been seen
# scollerdp3@spotify.com ------------------------->has ALREADY been seen
# cflooks7u@biblegateway.com ------------------------->has ALREADY been seen
# mspeero6@wordpress.com ------------------------->has ALREADY been seen
# htoppas65@pinterest.com ------------------------->has ALREADY been seen
# jmccourtie94@google.co.jp ------------------------->has ALREADY been seen
# khardibx@vistaprint.com ------------------------->has ALREADY been seen
# ncomberbachrq@ow.ly ------------------------->has ALREADY been seen
# mkwietekoi@tuttocitta.it ------------------------->has ALREADY been seen
# ofoxcroftiv@mac.com ------------------------->has ALREADY been seen
# cnewey6y@tumblr.com ------------------------->has ALREADY been seen
# rlodwickj9@shinystat.com ------------------------->has ALREADY been seen
# thewkin6q@people.com.cn ------------------------->has ALREADY been seen
# bandreoneno@people.com.cn ------------------------->has ALREADY been seen
# adegiorgiooo@sitemeter.com ------------------------->has ALREADY been seen
# aaberkirdopa@hhs.gov ------------------------->has ALREADY been seen
# rribbensos@hp.com ------------------------->has ALREADY been seen
# tvalentinettibk@home.pl ------------------------->has ALREADY been seen
# dgiorgeschi1b@vk.com ------------------------->has ALREADY been seen
# dpicktonrf@zimbio.com ------------------------->has ALREADY been seen
# mhartnellf8@businessinsider.com ------------------------->has ALREADY been seen
# gkarlolaked@smh.com.au ------------------------->has ALREADY been seen
# alimbfy@delicious.com ------------------------->has ALREADY been seen
# gpankettmanrg@nih.gov ------------------------->has ALREADY been seen
# robeirnebw@ehow.com ------------------------->has ALREADY been seen
# vvittoregk@stumbleupon.com ------------------------->has ALREADY been seen
# ngarthlandac@mozilla.com ------------------------->has ALREADY been seen
# skender4j@alexa.com ------------------------->has ALREADY been seen
# cdinglede@alexa.com ------------------------->has ALREADY been seen
# raddionizioob@livejournal.com ------------------------->has ALREADY been seen
# tlusty1u@fc2.com ------------------------->has ALREADY been seen
# rwestwellby@xinhuanet.com ------------------------->has ALREADY been seen
# creidshawpm@stanford.edu ------------------------->has ALREADY been seen
# jpettisalloy@ebay.com ------------------------->has ALREADY been seen
# mcastagnasso49@intel.com ------------------------->has ALREADY been seen
# dmurpheymq@google.com.au ------------------------->has ALREADY been seen
# fmelson8o@usda.gov ------------------------->has ALREADY been seen
# gpersed3@va.gov ------------------------->has ALREADY been seen
# rwalbridge2q@google.pl ------------------------->has ALREADY been seen
# hposnette8x@yale.edu ------------------------->has ALREADY been seen
# khessay82@ftc.gov ------------------------->has ALREADY been seen
# fmactrustey5b@cpanel.net ------------------------->has ALREADY been seen
# gnorthleighg2@patch.com ------------------------->has ALREADY been seen
# hswynley6r@linkedin.com ------------------------->has ALREADY been seen
# aeakly8x@fda.gov ------------------------->has ALREADY been seen
# jmackimm99@fastcompany.com ------------------------->has ALREADY been seen
# hpelchatam@vistaprint.com ------------------------->has ALREADY been seen
# fnairnsep@bbb.org ------------------------->has ALREADY been seen
# tcarnihanj8@toplist.cz ------------------------->has ALREADY been seen
# adolesk3@alibaba.com ------------------------->has ALREADY been seen
# ajennickad@abc.net.au ------------------------->has ALREADY been seen
# bkillelaybm@mozilla.com ------------------------->has ALREADY been seen
# cyateom@wordpress.org ------------------------->has ALREADY been seen
# mgrettonpw@ow.ly ------------------------->has ALREADY been seen
# mgommesrl@nature.com ------------------------->has ALREADY been seen
# dkenefickfq@arstechnica.com ------------------------->has ALREADY been seen
# pmillhilln9@github.io ------------------------->has ALREADY been seen
# darrighettihg@yellowbook.com ------------------------->has ALREADY been seen
# hbrookeseq@washington.edu ------------------------->has ALREADY been seen
# ...
# bgresham89@skyrock.com ------------------------->has ALREADY been seen
# cguilfoylejh@arizona.edu ------------------------->has ALREADY been seen
# djammepx@columbia.edu ------------------------->has ALREADY been seen
# gfrise96@godaddy.com ------------------------->has ALREADY been seen
# bbrompton1d@oracle.com ------------------------->has ALREADY been seen
# jeller5v@example.com ------------------------->has ALREADY been seen
# mliquorish8f@t.co ------------------------->has ALREADY been seen
# gwhitleybu@livejournal.com ------------------------->has ALREADY been seen
# krozziera9@answers.com ------------------------->has ALREADY been seen
# ltremoulet8g@indiegogo.com ------------------------->has ALREADY been seen
# ocuddyl@soup.io ------------------------->has ALREADY been seen
# cguillartkz@cbslocal.com ------------------------->has ALREADY been seen
# srenner6g@bloglovin.com ------------------------->has ALREADY been seen
# tjunenn@forbes.com ------------------------->has ALREADY been seen
# slubbockbw@histats.com ------------------------->has ALREADY been seen
# gmacallasterau@parallels.com ------------------------->has ALREADY been seen
# mcarsberg6i@columbia.edu ------------------------->has ALREADY been seen
# lloukeso5@ihg.com ------------------------->has ALREADY been seen
# sbotterman6g@edublogs.org ------------------------->has ALREADY been seen
# facarson3h@surveymonkey.com ------------------------->has ALREADY been seen
# pbyre4@prnewswire.com ------------------------->has ALREADY been seen
# cvamplusfb@boston.com ------------------------->has ALREADY been seen
# bmaylouri3@ustream.tv ------------------------->has ALREADY been seen
# lyakuntsovgv@trellian.com ------------------------->has ALREADY been seen
# tmctear5h@1688.com ------------------------->has ALREADY been seen
# tfurseh1@cdbaby.com ------------------------->has ALREADY been seen
# mdrysdellkf@jiathis.com ------------------------->has ALREADY been seen
# wladburykc@virginia.edu ------------------------->has ALREADY been seen
# bsanchiz8l@jiathis.com ------------------------->has ALREADY been seen
# ldoretqb@wordpress.com ------------------------->has ALREADY been seen
# btoffaloni8b@technorati.com ------------------------->has ALREADY been seen
# cauton2s@hc360.com ------------------------->has ALREADY been seen
# lvandermerwebd@abc.net.au ------------------------->has ALREADY been seen
# merbain4x@disqus.com ------------------------->has ALREADY been seen
# tgwinnellle@nature.com ------------------------->has ALREADY been seen
# tgarlanday@microsoft.com ------------------------->has ALREADY been seen
# ccantillion2u@tripod.com ------------------------->has ALREADY been seen
# oaizkovitchgr@sciencedirect.com ------------------------->has ALREADY been seen
# tantonellipu@jiathis.com ------------------------->has ALREADY been seen
# ahartgillog@xinhuanet.com ------------------------->has ALREADY been seen
# ffilpoib@theguardian.com ------------------------->has ALREADY been seen
# khallgoughci@hud.gov ------------------------->has ALREADY been seen
# ikobschjp@geocities.com ------------------------->has ALREADY been seen
# sbly1q@newsvine.com ------------------------->has ALREADY been seen
# rgaukrodge32@webmd.com ------------------------->has ALREADY been seen
# ebarthelmerm@list-manage.com ------------------------->has ALREADY been seen
# jbryersfx@slashdot.org ------------------------->has ALREADY been seen
# tlowrey1q@altervista.org ------------------------->has ALREADY been seen
# jcutcheedr@reuters.com ------------------------->has ALREADY been seen
# ldietzjy@live.com ------------------------->has ALREADY been seen
# rmckunepj@amazonaws.com ------------------------->has ALREADY been seen
# acolvill9m@wix.com ------------------------->has ALREADY been seen
# dpeaceyfs@narod.ru ------------------------->has ALREADY been seen
# sbridelle5@creativecommons.org ------------------------->has ALREADY been seen
# aminthorpeml@newyorker.com ------------------------->has ALREADY been seen
# mkirmondc6@reference.com ------------------------->has ALREADY been seen
# teacott54@oracle.com ------------------------->has ALREADY been seen
# cdoylandr6@qq.com ------------------------->has ALREADY been seen
# fpesticciolb@zdnet.com ------------------------->has ALREADY been seen
# ahuntingjh@nytimes.com ------------------------->has ALREADY been seen
# rworling8a@answers.com ------------------------->has ALREADY been seen
# abavesterc@domainmarket.com ------------------------->has ALREADY been seen
# amemoryo4@guardian.co.uk ------------------------->has ALREADY been seen
# bgammelhu@ow.ly ------------------------->has ALREADY been seen
# hstrettondj@netscape.com ------------------------->has ALREADY been seen
# craultbl@hatena.ne.jp ------------------------->has ALREADY been seen
# cpoinsett1u@google.com.au ------------------------->has ALREADY been seen
# gdeppend2@chron.com ------------------------->has ALREADY been seen
# dboijit@cam.ac.uk ------------------------->has ALREADY been seen
# slayland5r@blogger.com ------------------------->has ALREADY been seen
# fpimm5j@abc.net.au ------------------------->has ALREADY been seen
# mbearmanh4@craigslist.org ------------------------->has ALREADY been seen
# aaluardfr@oracle.com ------------------------->has ALREADY been seen
# dpalliserqo@wikipedia.org ------------------------->has ALREADY been seen
# dswattonl4@google.pl ------------------------->has ALREADY been seen
# jbaroschlw@geocities.jp ------------------------->has ALREADY been seen
# rcausleyam@youku.com ------------------------->has ALREADY been seen
# mbathoweak@fema.gov ------------------------->has ALREADY been seen
# amitskevichbj@google.nl ------------------------->has ALREADY been seen
# braouli5@instagram.com ------------------------->has ALREADY been seen
# mpettisct@techcrunch.com ------------------------->has ALREADY been seen
# poleszczakgo@cnbc.com ------------------------->has ALREADY been seen
# bcranchkb@state.gov ------------------------->has ALREADY been seen
# kmackettqq@upenn.edu ------------------------->has ALREADY been seen
# slamortf1@canalblog.com ------------------------->has ALREADY been seen
# uboyingtonpn@amazon.com ------------------------->has ALREADY been seen
# bcarles3e@ameblo.jp ------------------------->has ALREADY been seen
# rwellbeloved3r@storify.com ------------------------->has ALREADY been seen
# ibrandassi8r@economist.com ------------------------->has ALREADY been seen
# gferrieroih@amazon.co.uk ------------------------->has ALREADY been seen
# asailorlq@etsy.com ------------------------->has ALREADY been seen
# scastagneri79@columbia.edu ------------------------->has ALREADY been seen
# mlileye6@1688.com ------------------------->has ALREADY been seen
# kseiterpf@tmall.com ------------------------->has ALREADY been seen
# tdallmanjy@buzzfeed.com ------------------------->has ALREADY been seen
# jmcaviycy@zimbio.com ------------------------->has ALREADY been seen
# tcyseleyk7@ebay.co.uk ------------------------->has ALREADY been seen
# nfigiovannia4@canalblog.com ------------------------->has ALREADY been seen
# tskeeteje@yelp.com ------------------------->has ALREADY been seen
# bhaugeh3c@washingtonpost.com ------------------------->has ALREADY been seen
# tdumbarton8j@dedecms.com ------------------------->has ALREADY been seen
# kweighk6@state.tx.us ------------------------->has ALREADY been seen
# hmuddicliffep@amazon.co.jp ------------------------->has ALREADY been seen
# apachtox@tripod.com ------------------------->has ALREADY been seen
# bhayterc0@vk.com ------------------------->has ALREADY been seen
# fdullingnw@de.vu ------------------------->has ALREADY been seen
# shebbornepe@newsvine.com ------------------------->has ALREADY been seen
# friddef3@examiner.com ------------------------->has ALREADY been seen
# wscocroftkx@printfriendly.com ------------------------->has ALREADY been seen
# gbattyab@weibo.com ------------------------->has ALREADY been seen
# jshipm9@narod.ru ------------------------->has ALREADY been seen
# cbollettijz@mail.ru ------------------------->has ALREADY been seen
# msothcotteh@google.com.au ------------------------->has ALREADY been seen
# dkobiela77@opera.com ------------------------->has ALREADY been seen
# hferrarottihd@sun.com ------------------------->has ALREADY been seen
# egurrkx@google.pl ------------------------->has ALREADY been seen
# driguard6n@seattletimes.com ------------------------->has ALREADY been seen
# equesnech@google.ca ------------------------->has ALREADY been seen
# bcranage9j@about.me ------------------------->has ALREADY been seen
# lmilmoej0@hud.gov ------------------------->has ALREADY been seen
# cbrownhilll9@unc.edu ------------------------->has ALREADY been seen
# lbinnyhc@nymag.com ------------------------->has ALREADY been seen
# vstolliih@wordpress.org ------------------------->has ALREADY been seen
# in.pune.careers@3dplmsoftware.com ------------------------->has NOT been seen
# hr.admin@aahlaad.com ------------------------->has ALREADY been seen
# akash.shivnarayan@accenture.com ------------------------->has NOT been seen
# aruna.b.reddy@accenture.com ------------------------->has ALREADY been seen
# azharuddin.md@accenture.com ------------------------->has ALREADY been seen
# keerthi.raj@accenture.com ------------------------->has ALREADY been seen
# mailer@mailer.accenture.com ------------------------->has NOT been seen
# sudha.p.kumar@accenture.com ------------------------->has NOT been seen
# t.rahangdale@accenture.com ------------------------->has NOT been seen
# ankita.priya@accolite.com ------------------------->has ALREADY been seen
# mr1@acculogix.com ------------------------->has NOT been seen
# pr@acculogix.com ------------------------->has ALREADY been seen
# hr@accuversa.com ------------------------->has ALREADY been seen
# aparna.samal@adecco.co.in ------------------------->has ALREADY been seen
# neha.sahu@adecco.co.in ------------------------->has ALREADY been seen
# nisha.singh@adecco.co.in ------------------------->has ALREADY been seen
# mamatha.bamana@adecco.co.in ------------------------->has ALREADY been seen
# veena.venugopal@adecco.co.in ------------------------->has NOT been seen
# rohithnu@aditi.com ------------------------->has ALREADY been seen
# lathal@aditi.com ------------------------->has ALREADY been seen
# raghavendrab@aditi.com ------------------------->has ALREADY been seen
# shyamalapv@aditi.com ------------------------->has ALREADY been seen
# rohitku@adobe.com ------------------------->has ALREADY been seen
# careers@air-watch.com ------------------------->has ALREADY been seen
# support@ajr2.com ------------------------->has NOT been seen
# Careers@aletheia.co.in ------------------------->has ALREADY been seen
# lguntuma@allegisgroup.com ------------------------->has ALREADY been seen
# ssundare@allegisgroup.com ------------------------->has ALREADY been seen
# careers@alphalinxtech.com ------------------------->has ALREADY been seen
# archana.mehta@altisource.com ------------------------->has NOT been seen
# oliver.dsouza@altisource.com ------------------------->has NOT been seen
# ramchan@amazon.com ------------------------->has ALREADY been seen
# kirthiks@amazon.com ------------------------->has ALREADY been seen
# indujar@amazon.com ------------------------->has ALREADY been seen
# aritran@amazon.com ------------------------->has ALREADY been seen
# anisingh@amazon.com ------------------------->has ALREADY been seen
# deepama@amazon.com ------------------------->has NOT been seen
# edivya@amazon.com ------------------------->has ALREADY been seen
# suprita@amazon.com ------------------------->has NOT been seen
# risseyb@amazon.com ------------------------->has ALREADY been seen
# samtac@amazon.com ------------------------->has ALREADY been seen
# vivekmo@amazon.com ------------------------->has ALREADY been seen
# indiacareers@amdocs.com ------------------------->has ALREADY been seen
# info@aptean.com ------------------------->has ALREADY been seen
# Rajeshwari.Siddappa@aptean.com ------------------------->has ALREADY been seen
# Nishat.Fatma@aptean.com ------------------------->has NOT been seen
# nalinig@arcadix.com ------------------------->has ALREADY been seen
# jdivya.aranha@arcadix.com ------------------------->has ALREADY been seen
# jobs@arcadix.com ------------------------->has ALREADY been seen
# deepak@arcusinfotech.com ------------------------->has ALREADY been seen
# shamna@asapinfosystems.com ------------------------->has NOT been seen
# fefs@aspiresys.com ------------------------->has ALREADY been seen
# jobs@atlassystems.com ------------------------->has ALREADY been seen
# shilpa.veerabhadraiah@atlassystems.com ------------------------->has ALREADY been seen
# biju@augustainfotech.com ------------------------->has ALREADY been seen
# Praveen.d@avvasinfotech.com ------------------------->has NOT been seen
# bgsoftech@gmail.com ------------------------->has ALREADY been seen
# dilipsharma@blkashyap.com ------------------------->has ALREADY been seen
# ers@bsil.com ------------------------->has NOT been seen
# fixed-term.akanksha.sahay@in.bosch.com ------------------------->has NOT been seen
# hr@byt-eye.com ------------------------->has NOT been seen
# hr@calit8.com ------------------------->has NOT been seen
# contactus@calit8.com ------------------------->has NOT been seen
# Careers@cangonetworks.com ------------------------->has ALREADY been seen
# harsh.doshi@capgemini.com ------------------------->has ALREADY been seen
# jisha.balakrishnan@capgemini.com ------------------------->has NOT been seen
# kalpana.athi@capgemini.com ------------------------->has ALREADY been seen
# reshma.r@capgemini.com ------------------------->has ALREADY been seen
# vijaykumar.ninganure@capgemini.com ------------------------->has NOT been seen
# sailaja.yakasiri@capgemini.com ------------------------->has ALREADY been seen
# sunetra.das@capgemini.com ------------------------->has ALREADY been seen
# monika.shukla@capgemini.com ------------------------->has NOT been seen
# avijit.datta@capgemini.com ------------------------->has ALREADY been seen
# anand.subramanian@careernet.co.in ------------------------->has NOT been seen
# akankshya.dutta@careernet.co.in ------------------------->has NOT been seen
# sindhu.raman@careernet.co.in ------------------------->has NOT been seen
# hr@catalystwebexperts.com ------------------------->has ALREADY been seen
# lakshmi@centrisinfotech.com ------------------------->has ALREADY been seen
# jackson.johnson@centurylink.com ------------------------->has ALREADY been seen
# Niharika.Kala@centurylink.com ------------------------->has ALREADY been seen
# joseph@ceotalentsearch.com ------------------------->has ALREADY been seen
# ngottigundala@ciber.com ------------------------->has ALREADY been seen
# info@cigniti.com ------------------------->has ALREADY been seen
# wearehiring@cigniti.com ------------------------->has ALREADY been seen
# freshers@citagus.com ------------------------->has ALREADY been seen
# gayathri.srinivas@citrix.com ------------------------->has ALREADY been seen
# jobs@clifftechnologies.com ------------------------->has ALREADY been seen
# Manju.D2@cognizant.com ------------------------->has ALREADY been seen
# Mohammed.Moin@cognizant.com ------------------------->has ALREADY been seen
# priyanka.pramanick@cognizant.com ------------------------->has NOT been seen
# Raghavendra.Pawarr.c@cognizant.com ------------------------->has ALREADY been seen
# vigneswari.sivanandham@cognizant.com ------------------------->has NOT been seen
# suparna.dhar@cognizant.com ------------------------->has ALREADY been seen
# reshma.n@confrontsolutions.com ------------------------->has NOT been seen
# jobopenings@compassitesinc.com ------------------------->has ALREADY been seen
# jobs@corasent.com ------------------------->has NOT been seen
# pramila@covenantindia.net ------------------------->has ALREADY been seen
# monicae@covenantindia.net ------------------------->has ALREADY been seen
# smathur@csc.com ------------------------->has ALREADY been seen
# rm.south@cyberqindia.com ------------------------->has ALREADY been seen
# ######################################################################

# %%
from decimal import *
getcontext().prec = 100
prod=Decimal(1) / Decimal(n)
power=k*m
m1=prod**power
n1=(1-m1)
n2=(1-n1)
n3=n2**k

# %%
Prob=.00124
print("Probability will be(False Positive)",Prob)
print("Size of bit array",p)
print("Number of K hash Function",k)
print("False Positive",100-count2/k)
# Out:
# Probability will be(False Positive) 0.00124
# Size of bit array 28755
# Number of K hash Function 10
# False Positive 70.0
